# %% [markdown]
# In this notebook, we review material from previous lectures:
#
# * [ggplot](#ggplot)
#     * aesthetics
#     * geometries
#     * faceting
#     * statistical transformations
#     * position adjustments
#     * coordinate transformations
# * [dplyr verbs](#dplyr-verbs)
#     * filter
#     * arrange
#     * select
#     * rename
#     * mutate
#     * transmute
#     * group_by
#     * summarize
# * [pipes](#pipes)
# * [EDA](#EDA)
#     * visualizing distributions
#     * typical values
#     * unusual values
#     * missing values
#     * covariation

# %% [markdown]
# # ggplot

# %%
options(repr.plot.width=6, repr.plot.height=4)
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# What's wrong with this code to produce a scatter plot of `hwy` vs `displ` with the `color` aesthetic mapped to `drv`?

# %%
ggplot(data = mpg) +
    geom_point(mapping = aes(x = displ, y = hwy, color = drv))
# Out:
# plot without title

# %% [markdown]
# What does `se = FALSE` do in the code below?

# %%
ggplot(data = mpg) +
    geom_smooth(mapping = aes(x = displ, y = hwy), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# It sets the standard error to FALSE, i.e., the gray regions around the fitted curve will not be displayed.

# %% [markdown]
# Write the command to produce the following plot.
#
# ![plot](http://dept.stat.lsa.umich.edu/~tewaria/teaching/STATS306-Fall2017/Rplot1.png)

# %%
ggplot(data=mpg, mapping=aes(x=displ,y=hwy)) +
    geom_point() +
    geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# Write the command to produce the following plot.
#
# ![plot](http://dept.stat.lsa.umich.edu/~tewaria/teaching/STATS306-Fall2017/Rplot2.png)

# %%
ggplot(data=mpg, mapping=aes(x=displ,y=hwy,color=drv)) +
    geom_point() +
    geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# Match the geometries below with their statistical transformations.
#
# | Geometry       | Stat     |
# |----------------|----------|
# | geom_point     | bin      |
# | geom_histogram | count    |
# | geom_bar       | identity |

# %% [markdown]
# Answer:
#
# | Geometry       | Stat     |
# |----------------|----------|
# | geom_point     | identity |
# | geom_histogram | identity |
# | geom_bar       | count    |

# %% [markdown]
# Write the command to produce the following plot.
#
# ![plot](http://dept.stat.lsa.umich.edu/~tewaria/teaching/STATS306-Fall2017/Rplot3.png)

# %%
ggplot(data=mpg) +
    geom_bar(mapping=aes(x=class,fill=drv))
# Out:
# plot without title

# %% [markdown]
# Write the command to produce the following plot.
#
# ![plot](http://dept.stat.lsa.umich.edu/~tewaria/teaching/STATS306-Fall2017/Rplot4.png)

# %%
ggplot(data=mpg) +
    geom_bar(mapping=aes(x=class,fill=drv)) +
    coord_flip()
# Out:
# plot without title

# %% [markdown]
# # dplyr verbs

# %% [markdown]
# What's wrong in the code fragments below?

# %%
filter(mpg, drv == f) # find vehicles with front wheel drive
# Out:
# Error: object 'f' not found
# Traceback:
#
# 1. filter(mpg, drv == f)
# 2. filter.tbl_df(mpg, drv == f)
# 3. filter_impl(.data, quo)

# %%
# f should be in quotes since drv is of chr type
filter(mpg, drv == "f")
# Out:
#     manufacturer model       displ year cyl trans      drv cty hwy fl
# 1   audi         a4          1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4          1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4          2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4          2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4          2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4          2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4          3.1   2008 6   auto(av)   f   18  27  p
# 8   chevrolet    malibu      2.4   1999 4   auto(l4)   f   19  27  r
# 9   chevrolet    malibu      2.4   2008 4   auto(l4)   f   22  30  r
# 10  chevrolet    malibu      3.1   1999 6   auto(l4)   f   18  26  r
# 11  chevrolet    malibu      3.5   2008 6   auto(l4)   f   18  29  r
# 12  chevrolet    malibu      3.6   2008 6   auto(s6)   f   17  26  r
# 13  dodge        caravan 2wd 2.4   1999 4   auto(l3)   f   18  24  r
# 14  dodge        caravan 2wd 3.0   1999 6   auto(l4)   f   17  24  r
# 15  dodge        caravan 2wd 3.3   1999 6   auto(l4)   f   16  22  r
# 16  dodge        caravan 2wd 3.3   1999 6   auto(l4)   f   16  22  r
# 17  dodge        caravan 2wd 3.3   2008 6   auto(l4)   f   17  24  r
# 18  dodge        caravan 2wd 3.3   2008 6   auto(l4)   f   17  24  r
# 19  dodge        caravan 2wd 3.3   2008 6   auto(l4)   f   11  17  e
# 20  dodge        caravan 2wd 3.8   1999 6   auto(l4)   f   15  22  r
# 21  dodge        caravan 2wd 3.8   1999 6   auto(l4)   f   15  21  r
# 22  dodge        caravan 2wd 3.8   2008 6   auto(l6)   f   16  23  r
# 23  dodge        caravan 2wd 4.0   2008 6   auto(l6)   f   16  23  r
# 24  honda        civic       1.6   1999 4   manual(m5) f   28  33  r
# 25  honda        civic       1.6   1999 4   auto(l4)   f   24  32  r
# 26  honda        civic       1.6   1999 4   manual(m5) f   25  32  r
# 27  honda        civic       1.6   1999 4   manual(m5) f   23  29  p
# 28  honda        civic       1.6   1999 4   auto(l4)   f   24  32  r
# 29  honda        civic       1.8   2008 4   manual(m5) f   26  34  r
# 30  honda        civic       1.8   2008 4   auto(l5)   f   25  36  r
# ⋮   ⋮            ⋮           ⋮     ⋮    ⋮   ⋮          ⋮   ⋮   ⋮   ⋮
# 77  toyota       corolla     1.8   1999 4   manual(m5) f   26  35  r
# 78  toyota       corolla     1.8   2008 4   manual(m5) f   28  37  r
# 79  toyota       corolla     1.8   2008 4   auto(l4)   f   26  35  r
# 80  volkswagen   gti         2.0   1999 4   manual(m5) f   21  29  r
# 81  volkswagen   gti         2.0   1999 4   auto(l4)   f   19  26  r
# 82  volkswagen   gti         2.0   2008 4   manual(m6) f   21  29  p
# 83  volkswagen   gti         2.0   2008 4   auto(s6)   f   22  29  p
# 84  volkswagen   gti         2.8   1999 6   manual(m5) f   17  24  r
# 85  volkswagen   jetta       1.9   1999 4   manual(m5) f   33  44  d
# 86  volkswagen   jetta       2.0   1999 4   manual(m5) f   21  29  r
# 87  volkswagen   jetta       2.0   1999 4   auto(l4)   f   19  26  r
# 88  volkswagen   jetta       2.0   2008 4   auto(s6)   f   22  29  p
# 89  volkswagen   jetta       2.0   2008 4   manual(m6) f   21  29  p
# 90  volkswagen   jetta       2.5   2008 5   auto(s6)   f   21  29  r
# 91  volkswagen   jetta       2.5   2008 5   manual(m5) f   21  29  r
# 92  volkswagen   jetta       2.8   1999 6   auto(l4)   f   16  23  r
# 93  volkswagen   jetta       2.8   1999 6   manual(m5) f   17  24  r
# 94  volkswagen   new beetle  1.9   1999 4   manual(m5) f   35  44  d
# 95  volkswagen   new beetle  1.9   1999 4   auto(l4)   f   29  41  d
# 96  volkswagen   new beetle  2.0   1999 4   manual(m5) f   21  29  r
# 97  volkswagen   new beetle  2.0   1999 4   auto(l4)   f   19  26  r
# 98  volkswagen   new beetle  2.5   2008 5   manual(m5) f   20  28  r
# 99  volkswagen   new beetle  2.5   2008 5   auto(s6)   f   20  29  r
# 100 volkswagen   passat      1.8   1999 4   manual(m5) f   21  29  p
# 101 volkswagen   passat      1.8   1999 4   auto(l5)   f   18  29  p
# 102 volkswagen   passat      2.0   2008 4   auto(s6)   f   19  28  p
# 103 volkswagen   passat      2.0   2008 4   manual(m6) f   21  29  p
# 104 volkswagen   passat      2.8   1999 6   auto(l5)   f   16  26  p
# 105 volkswagen   passat      2.8   1999 6   manual(m5) f   18  26  p
# 106 volkswagen   passat      3.6   2008 6   auto(s6)   f   17  26  p
#     class
# 1   compact
# 2   compact
# 3   compact
# 4   compact
# 5   compact
# 6   compact
# 7   compact
# 8   midsize
# 9   midsize
# 10  midsize
# 11  midsize
# 12  midsize
# 13  minivan
# 14  minivan
# 15  minivan
# 16  minivan
# 17  minivan
# 18  minivan
# 19  minivan
# 20  minivan
# 21  minivan
# 22  minivan
# 23  minivan
# 24  subcompact
# 25  subcompact
# 26  subcompact
# 27  subcompact
# 28  subcompact
# 29  subcompact
# 30  subcompact
# ⋮   ⋮
# 77  compact
# 78  compact
# 79  compact
# 80  compact
# 81  compact
# 82  compact
# 83  compact
# 84  compact
# 85  compact
# 86  compact
# 87  compact
# 88  compact
# 89  compact
# 90  compact
# 91  compact
# 92  compact
# 93  compact
# 94  subcompact
# 95  subcompact
# 96  subcompact
# 97  subcompact
# 98  subcompact
# 99  subcompact
# 100 midsize
# 101 midsize
# 102 midsize
# 103 midsize
# 104 midsize
# 105 midsize
# 106 midsize

# %%
filter(mpg, drv <> '4')) # find vehicles that do not have 4 wheel drives
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:18: unexpected '>'
# 1: filter(mpg, drv <>
#                      ^
# Traceback:

# %%
# the R operator for inequality is !=, also the second right parenthesis isn't needed
filter(mpg, drv != '4')
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 9   chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   11  15  e
# 10  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 11  chevrolet    c1500 suburban 2wd 5.7   1999 8   auto(l4)   r   13  17  r
# 12  chevrolet    c1500 suburban 2wd 6.0   2008 8   auto(l4)   r   12  17  r
# 13  chevrolet    corvette           5.7   1999 8   manual(m6) r   16  26  p
# 14  chevrolet    corvette           5.7   1999 8   auto(l4)   r   15  23  p
# 15  chevrolet    corvette           6.2   2008 8   manual(m6) r   16  26  p
# 16  chevrolet    corvette           6.2   2008 8   auto(s6)   r   15  25  p
# 17  chevrolet    corvette           7.0   2008 8   manual(m6) r   15  24  p
# 18  chevrolet    malibu             2.4   1999 4   auto(l4)   f   19  27  r
# 19  chevrolet    malibu             2.4   2008 4   auto(l4)   f   22  30  r
# 20  chevrolet    malibu             3.1   1999 6   auto(l4)   f   18  26  r
# 21  chevrolet    malibu             3.5   2008 6   auto(l4)   f   18  29  r
# 22  chevrolet    malibu             3.6   2008 6   auto(s6)   f   17  26  r
# 23  dodge        caravan 2wd        2.4   1999 4   auto(l3)   f   18  24  r
# 24  dodge        caravan 2wd        3.0   1999 6   auto(l4)   f   17  24  r
# 25  dodge        caravan 2wd        3.3   1999 6   auto(l4)   f   16  22  r
# 26  dodge        caravan 2wd        3.3   1999 6   auto(l4)   f   16  22  r
# 27  dodge        caravan 2wd        3.3   2008 6   auto(l4)   f   17  24  r
# 28  dodge        caravan 2wd        3.3   2008 6   auto(l4)   f   17  24  r
# 29  dodge        caravan 2wd        3.3   2008 6   auto(l4)   f   11  17  e
# 30  dodge        caravan 2wd        3.8   1999 6   auto(l4)   f   15  22  r
# ⋮   ⋮            ⋮                  ⋮     ⋮    ⋮   ⋮          ⋮   ⋮   ⋮   ⋮
# 102 toyota       corolla            1.8   1999 4   manual(m5) f   26  35  r
# 103 toyota       corolla            1.8   2008 4   manual(m5) f   28  37  r
# 104 toyota       corolla            1.8   2008 4   auto(l4)   f   26  35  r
# 105 volkswagen   gti                2.0   1999 4   manual(m5) f   21  29  r
# 106 volkswagen   gti                2.0   1999 4   auto(l4)   f   19  26  r
# 107 volkswagen   gti                2.0   2008 4   manual(m6) f   21  29  p
# 108 volkswagen   gti                2.0   2008 4   auto(s6)   f   22  29  p
# 109 volkswagen   gti                2.8   1999 6   manual(m5) f   17  24  r
# 110 volkswagen   jetta              1.9   1999 4   manual(m5) f   33  44  d
# 111 volkswagen   jetta              2.0   1999 4   manual(m5) f   21  29  r
# 112 volkswagen   jetta              2.0   1999 4   auto(l4)   f   19  26  r
# 113 volkswagen   jetta              2.0   2008 4   auto(s6)   f   22  29  p
# 114 volkswagen   jetta              2.0   2008 4   manual(m6) f   21  29  p
# 115 volkswagen   jetta              2.5   2008 5   auto(s6)   f   21  29  r
# 116 volkswagen   jetta              2.5   2008 5   manual(m5) f   21  29  r
# 117 volkswagen   jetta              2.8   1999 6   auto(l4)   f   16  23  r
# 118 volkswagen   jetta              2.8   1999 6   manual(m5) f   17  24  r
# 119 volkswagen   new beetle         1.9   1999 4   manual(m5) f   35  44  d
# 120 volkswagen   new beetle         1.9   1999 4   auto(l4)   f   29  41  d
# 121 volkswagen   new beetle         2.0   1999 4   manual(m5) f   21  29  r
# 122 volkswagen   new beetle         2.0   1999 4   auto(l4)   f   19  26  r
# 123 volkswagen   new beetle         2.5   2008 5   manual(m5) f   20  28  r
# 124 volkswagen   new beetle         2.5   2008 5   auto(s6)   f   20  29  r
# 125 volkswagen   passat             1.8   1999 4   manual(m5) f   21  29  p
# 126 volkswagen   passat             1.8   1999 4   auto(l5)   f   18  29  p
# 127 volkswagen   passat             2.0   2008 4   auto(s6)   f   19  28  p
# 128 volkswagen   passat             2.0   2008 4   manual(m6) f   21  29  p
# 129 volkswagen   passat             2.8   1999 6   auto(l5)   f   16  26  p
# 130 volkswagen   passat             2.8   1999 6   manual(m5) f   18  26  p
# 131 volkswagen   passat             3.6   2008 6   auto(s6)   f   17  26  p
#     class
# 1   compact
# 2   compact
# 3   compact
# 4   compact
# 5   compact
# 6   compact
# 7   compact
# 8   suv
# 9   suv
# 10  suv
# 11  suv
# 12  suv
# 13  2seater
# 14  2seater
# 15  2seater
# 16  2seater
# 17  2seater
# 18  midsize
# 19  midsize
# 20  midsize
# 21  midsize
# 22  midsize
# 23  minivan
# 24  minivan
# 25  minivan
# 26  minivan
# 27  minivan
# 28  minivan
# 29  minivan
# 30  minivan
# ⋮   ⋮
# 102 compact
# 103 compact
# 104 compact
# 105 compact
# 106 compact
# 107 compact
# 108 compact
# 109 compact
# 110 compact
# 111 compact
# 112 compact
# 113 compact
# 114 compact
# 115 compact
# 116 compact
# 117 compact
# 118 compact
# 119 subcompact
# 120 subcompact
# 121 subcompact
# 122 subcompact
# 123 subcompact
# 124 subcompact
# 125 midsize
# 126 midsize
# 127 midsize
# 128 midsize
# 129 midsize
# 130 midsize
# 131 midsize

# %%
filter(mpg, manufacturer = toyota & class = suv) # find all suvs made by toyota
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:43: unexpected '='
# 1: filter(mpg, manufacturer = toyota & class =
#                                               ^
# Traceback:

# %%
# toyota and suv should be in quotes, and test of equality needs ==
filter(mpg, manufacturer == "toyota" & class == "suv")
# Out:
#   manufacturer model                  displ year cyl trans      drv cty hwy fl
# 1 toyota       4runner 4wd            2.7   1999 4   manual(m5) 4   15  20  r
# 2 toyota       4runner 4wd            2.7   1999 4   auto(l4)   4   16  20  r
# 3 toyota       4runner 4wd            3.4   1999 6   auto(l4)   4   15  19  r
# 4 toyota       4runner 4wd            3.4   1999 6   manual(m5) 4   15  17  r
# 5 toyota       4runner 4wd            4.0   2008 6   auto(l5)   4   16  20  r
# 6 toyota       4runner 4wd            4.7   2008 8   auto(l5)   4   14  17  r
# 7 toyota       land cruiser wagon 4wd 4.7   1999 8   auto(l4)   4   11  15  r
# 8 toyota       land cruiser wagon 4wd 5.7   2008 8   auto(s6)   4   13  18  r
#   class
# 1 suv
# 2 suv
# 3 suv
# 4 suv
# 5 suv
# 6 suv
# 7 suv
# 8 suv

# %%
number_of(filter(mpg, cyl == 4)) # find the number of vehicle with 4 cylinders
# Out:
# Error in number_of(filter(mpg, cyl == 4)): could not find function "number_of"
# Traceback:

# %%
# nrow computes no. of rows in a tibble (and ncol computes no. of columns)
nrow(filter(mpg, cyl == 4))
# Out:
# [1] 81

# %% [markdown]
# # pipes

# %% [markdown]
# What's wrong in the code fragments below?

# %%
# show only the highway mileage of suvs sorted in descending order of the mileage
select(mpg, hwy) %>%
    filter(class == 'suv') %>%
    arrange(hwy)
# Out:
# Error in class == "suv": comparison (1) is possible only for atomic and list types
# Traceback:
#
# 1. select(mpg, hwy) %>% filter(class == "suv") %>% arrange(hwy)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. function_list[[i]](value)
# 8. filter(., class == "suv")
# 9. filter.tbl_df(., class == "suv")
# 10. filter_impl(.data, quo)

# %%
filter(mpg, class == 'suv') %>%
    select(hwy) %>%
    arrange(hwy)
# Out:
#    hwy
# 1  12
# 2  12
# 3  14
# 4  14
# 5  15
# 6  15
# 7  15
# 8  15
# 9  15
# 10 15
# 11 16
# 12 16
# 13 17
# 14 17
# 15 17
# 16 17
# 17 17
# 18 17
# 19 17
# 20 17
# 21 17
# 22 17
# 23 17
# 24 17
# 25 17
# 26 17
# 27 17
# 28 17
# 29 17
# 30 17
# ⋮  ⋮
# 33 18
# 34 18
# 35 18
# 36 18
# 37 18
# 38 18
# 39 18
# 40 19
# 41 19
# 42 19
# 43 19
# 44 19
# 45 19
# 46 19
# 47 19
# 48 19
# 49 20
# 50 20
# 51 20
# 52 20
# 53 20
# 54 20
# 55 20
# 56 22
# 57 23
# 58 24
# 59 25
# 60 25
# 61 26
# 62 27

# %%
# depth variable in diamonds is supposed to be the ratio (as a percentage) between z and mean of x,y
# add a new column new_depth where we compute it ourselves
# assign it to a variable called new_diamonds
mutate(diamonds, new_depth <- 100*2*z/(x+y)) %>%
    new_diamonds
# Out:
# Error in new_diamonds(.): could not find function "new_diamonds"
# Traceback:
#
# 1. mutate(diamonds, new_depth <- 100 * 2 * z/(x + y)) %>% new_diamonds
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)

# %%
new_diamonds <- mutate(diamonds, new_depth = 100*2*z/(x+y))

# %%
# check if depth and new_depth are close to each other within machine precision
filter(new_diamonds, depth == new_depth)
# Out:
#     carat cut       color clarity depth table price x    y    z    new_depth
# 1   0.71  Ideal     F     SI1     62.5  55    2788  5.71 5.65 3.55 62.5
# 2   0.80  Very Good E     SI2     62.5  56    2804  5.88 5.96 3.70 62.5
# 3   0.79  Ideal     H     VS2     62.5  57    2844  5.91 5.93 3.70 62.5
# 4   0.80  Ideal     G     SI1     62.5  57    2870  5.94 5.90 3.70 62.5
# 5   0.62  Ideal     E     VVS2    62.0  56    2904  5.48 5.52 3.41 62.0
# 6   0.74  Premium   F     VS1     62.5  60    2917  5.78 5.74 3.60 62.5
# 7   0.70  Very Good D     VS2     62.5  55    3052  5.65 5.71 3.55 62.5
# 8   0.32  Premium   H     VS1     62.4  58     561  4.35 4.40 2.73 62.4
# 9   0.91  Fair      E     SI2     64.5  60    3119  6.04 5.96 3.87 64.5
# 10  1.02  Premium   H     I1      62.5  60    3141  6.39 6.41 4.00 62.5
# 11  0.90  Very Good H     SI2     59.2  61    3160  6.23 6.27 3.70 59.2
# 12  0.90  Ideal     J     VS1     62.5  55    3175  6.18 6.14 3.85 62.5
# 13  0.90  Very Good J     VS1     62.5  56    3188  6.11 6.21 3.85 62.5
# 14  1.02  Premium   H     I1      62.5  60    3199  6.41 6.39 4.00 62.5
# 15  0.90  Very Good I     VS2     62.5  57    3209  6.12 6.20 3.85 62.5
# 16  0.81  Premium   F     SI1     61.0  59    3230  6.01 5.99 3.66 61.0
# 17  0.91  Premium   G     SI1     62.5  56    3262  6.30 6.18 3.90 62.5
# 18  0.91  Good      F     SI1     64.0  57    3363  6.17 6.08 3.92 64.0
# 19  0.91  Good      F     SI1     64.0  57    3423  6.08 6.17 3.92 64.0
# 20  0.78  Premium   E     VS1     62.5  57    3444  5.94 5.90 3.70 62.5
# 21  0.80  Premium   G     VS1     62.5  58    3514  5.90 5.94 3.70 62.5
# 22  0.90  Good      H     VS2     64.0  57    3538  6.14 6.11 3.92 64.0
# 23  0.91  Very Good I     VS2     62.5  58    3579  6.13 6.19 3.85 62.5
# 24  0.90  Good      H     VS2     64.0  57    3601  6.11 6.14 3.92 64.0
# 25  0.90  Premium   H     SI1     60.0  56    3629  6.33 6.27 3.78 60.0
# 26  1.03  Fair      D     SI2     66.4  56    3743  6.31 6.19 4.15 66.4
# 27  1.04  Premium   I     SI2     62.0  57    3774  6.53 6.47 4.03 62.0
# 28  1.04  Premium   I     SI2     62.0  57    3774  6.53 6.47 4.03 62.0
# 29  1.17  Fair      I     SI2     59.2  68    3833  6.91 6.84 4.07 59.2
# 30  1.02  Very Good J     SI1     62.5  58    3857  6.37 6.43 4.00 62.5
# ⋮   ⋮     ⋮         ⋮     ⋮       ⋮     ⋮     ⋮     ⋮    ⋮    ⋮    ⋮
# 205 0.53  Ideal     G     VVS2    62.5  54    1818  5.19 5.21 3.25 62.5
# 206 0.23  Very Good E     VVS2    60.0  56     530  4.03 4.07 2.43 60.0
# 207 0.23  Very Good E     VVS1    60.0  59     530  3.97 4.03 2.40 60.0
# 208 0.23  Ideal     F     VVS2    61.0  57     530  3.98 4.02 2.44 61.0
# 209 0.53  Ideal     G     VVS2    62.5  54    1914  5.21 5.19 3.25 62.5
# 210 0.70  Fair      G     SI1     66.0  53    1949  5.53 5.47 3.63 66.0
# 211 0.51  Ideal     D     VS2     62.5  56    2056  5.13 5.11 3.20 62.5
# 212 0.51  Very Good E     VVS2    60.0  58    2062  5.19 5.21 3.12 60.0
# 213 0.24  Ideal     F     VVS2    61.5  56     540  3.99 4.01 2.46 61.5
# 214 0.32  Premium   G     SI2     62.4  59     540  4.40 4.35 2.73 62.4
# 215 0.71  Premium   H     SI1     62.4  59    2112  5.65 5.60 3.51 62.4
# 216 0.61  Good      F     VS1     60.0  65    2196  5.53 5.47 3.30 60.0
# 217 0.71  Ideal     G     SI1     62.5  57    2215  5.72 5.64 3.55 62.5
# 218 0.70  Ideal     I     VS2     62.5  56    2232  5.66 5.70 3.55 62.5
# 219 0.70  Very Good H     VS2     60.0  55    2287  5.73 5.77 3.45 60.0
# 220 0.71  Very Good F     SI1     64.0  58    2345  5.59 5.66 3.60 64.0
# 221 0.91  Good      I     SI1     64.0  58    2348  6.01 5.99 3.84 64.0
# 222 0.73  Ideal     G     SI1     62.5  55    2351  5.78 5.74 3.60 62.5
# 223 0.31  Ideal     G     VS2     62.4  54     544  4.36 4.39 2.73 62.4
# 224 0.70  Good      F     VS1     64.0  56    2401  5.60 5.65 3.60 64.0
# 225 0.47  Ideal     D     VVS1    62.0  54    2460  4.99 5.01 3.10 62.0
# 226 0.70  Ideal     G     SI1     62.5  56    2478  5.67 5.69 3.55 62.5
# 227 0.81  Premium   G     SI2     62.5  57    2515  5.95 5.89 3.70 62.5
# 228 0.70  Very Good G     VS2     60.0  58    2527  5.73 5.77 3.45 60.0
# 229 0.73  Ideal     G     VS2     62.5  56    2586  5.78 5.74 3.60 62.5
# 230 0.72  Ideal     I     VS1     62.5  55    2586  5.74 5.78 3.60 62.5
# 231 0.71  Ideal     G     SI1     62.5  57    2604  5.67 5.69 3.55 62.5
# 232 0.70  Very Good E     SI1     62.5  59    2617  5.66 5.70 3.55 62.5
# 233 0.71  Premium   E     VS2     62.5  60    2735  5.70 5.66 3.55 62.5
# 234 0.70  Very Good G     VS1     60.0  56    2741  5.77 5.83 3.48 60.0

# %%
filter(new_diamonds, near(depth, new_depth))
# Out:
#     carat cut       color clarity depth table price x    y    z    new_depth
# 1   0.71  Ideal     F     SI1     62.5  55    2788  5.71 5.65 3.55 62.5
# 2   0.80  Very Good E     SI2     62.5  56    2804  5.88 5.96 3.70 62.5
# 3   0.79  Ideal     H     VS2     62.5  57    2844  5.91 5.93 3.70 62.5
# 4   0.79  Premium   D     SI2     60.0  60    2853  6.07 6.03 3.63 60.0
# 5   0.80  Ideal     G     SI1     62.5  57    2870  5.94 5.90 3.70 62.5
# 6   0.62  Ideal     E     VVS2    62.0  56    2904  5.48 5.52 3.41 62.0
# 7   0.74  Premium   F     VS1     62.5  60    2917  5.78 5.74 3.60 62.5
# 8   0.70  Very Good D     VS2     62.5  55    3052  5.65 5.71 3.55 62.5
# 9   0.32  Premium   H     VS1     62.4  58     561  4.35 4.40 2.73 62.4
# 10  0.91  Fair      E     SI2     64.5  60    3119  6.04 5.96 3.87 64.5
# 11  1.02  Premium   H     I1      62.5  60    3141  6.39 6.41 4.00 62.5
# 12  0.90  Very Good H     SI2     59.2  61    3160  6.23 6.27 3.70 59.2
# 13  0.90  Ideal     J     VS1     62.5  55    3175  6.18 6.14 3.85 62.5
# 14  0.32  Ideal     G     VS2     62.5  56     561  4.38 4.42 2.75 62.5
# 15  0.90  Very Good J     VS1     62.5  56    3188  6.11 6.21 3.85 62.5
# 16  1.02  Premium   H     I1      62.5  60    3199  6.41 6.39 4.00 62.5
# 17  0.90  Very Good I     VS2     62.5  57    3209  6.12 6.20 3.85 62.5
# 18  0.81  Premium   F     SI1     61.0  59    3230  6.01 5.99 3.66 61.0
# 19  0.26  Ideal     E     VVS2    62.5  55     564  4.07 4.09 2.55 62.5
# 20  0.91  Premium   G     SI1     62.5  56    3262  6.30 6.18 3.90 62.5
# 21  0.91  Good      F     SI1     64.0  57    3363  6.17 6.08 3.92 64.0
# 22  0.91  Good      F     SI1     64.0  57    3423  6.08 6.17 3.92 64.0
# 23  0.78  Premium   E     VS1     62.5  57    3444  5.94 5.90 3.70 62.5
# 24  0.36  Very Good H     VS2     60.0  62     568  4.58 4.62 2.76 60.0
# 25  0.80  Premium   G     VS1     62.5  58    3514  5.90 5.94 3.70 62.5
# 26  0.90  Good      H     VS2     64.0  57    3538  6.14 6.11 3.92 64.0
# 27  0.91  Very Good I     VS2     62.5  58    3579  6.13 6.19 3.85 62.5
# 28  0.90  Good      H     VS2     64.0  57    3601  6.11 6.14 3.92 64.0
# 29  0.90  Premium   H     SI1     60.0  56    3629  6.33 6.27 3.78 60.0
# 30  1.03  Fair      D     SI2     66.4  56    3743  6.31 6.19 4.15 66.4
# ⋮   ⋮     ⋮         ⋮     ⋮       ⋮     ⋮     ⋮     ⋮    ⋮    ⋮    ⋮
# 352 0.24  Ideal     F     VVS2    61.5  56.0   540  3.99 4.01 2.46 61.5
# 353 0.32  Premium   G     SI2     62.4  59.0   540  4.40 4.35 2.73 62.4
# 354 0.71  Premium   H     SI1     62.4  59.0  2112  5.65 5.60 3.51 62.4
# 355 0.61  Good      F     VS1     60.0  65.0  2196  5.53 5.47 3.30 60.0
# 356 0.71  Ideal     G     SI1     62.5  57.0  2215  5.72 5.64 3.55 62.5
# 357 0.70  Ideal     I     VS2     62.5  56.0  2232  5.66 5.70 3.55 62.5
# 358 0.65  Good      G     VS1     60.0  60.4  2241  5.60 5.70 3.39 60.0
# 359 0.70  Premium   F     SI1     62.5  62.0  2268  5.63 5.57 3.50 62.5
# 360 0.70  Very Good H     VS2     60.0  55.0  2287  5.73 5.77 3.45 60.0
# 361 0.56  Ideal     D     VS1     62.5  56.0  2292  5.26 5.30 3.30 62.5
# 362 0.71  Very Good F     SI1     64.0  58.0  2345  5.59 5.66 3.60 64.0
# 363 0.91  Good      I     SI1     64.0  58.0  2348  6.01 5.99 3.84 64.0
# 364 0.73  Ideal     G     SI1     62.5  55.0  2351  5.78 5.74 3.60 62.5
# 365 0.31  Ideal     G     VS2     62.4  54.0   544  4.36 4.39 2.73 62.4
# 366 0.70  Good      F     VS1     64.0  56.0  2401  5.60 5.65 3.60 64.0
# 367 0.47  Ideal     D     VVS1    62.0  54.0  2460  4.99 5.01 3.10 62.0
# 368 0.70  Ideal     G     SI1     62.5  56.0  2478  5.67 5.69 3.55 62.5
# 369 0.57  Very Good E     VVS2    60.0  61.0  2485  5.36 5.44 3.24 60.0
# 370 0.57  Premium   E     VVS2    60.0  61.0  2507  5.44 5.36 3.24 60.0
# 371 0.81  Premium   G     SI2     62.5  57.0  2515  5.95 5.89 3.70 62.5
# 372 0.70  Very Good G     VS2     60.0  58.0  2527  5.73 5.77 3.45 60.0
# 373 0.73  Ideal     G     VS2     62.5  56.0  2586  5.78 5.74 3.60 62.5
# 374 0.72  Ideal     I     VS1     62.5  55.0  2586  5.74 5.78 3.60 62.5
# 375 0.71  Ideal     G     SI1     62.5  57.0  2604  5.67 5.69 3.55 62.5
# 376 0.59  Ideal     G     IF      62.5  57.0  2611  5.34 5.38 3.35 62.5
# 377 0.70  Very Good E     SI1     62.5  59.0  2617  5.66 5.70 3.55 62.5
# 378 0.70  Very Good F     SI1     62.5  59.0  2672  5.66 5.54 3.50 62.5
# 379 0.71  Premium   E     VS2     62.5  60.0  2735  5.70 5.66 3.55 62.5
# 380 0.70  Very Good G     VS1     60.0  56.0  2741  5.77 5.83 3.48 60.0
# 381 0.77  Premium   F     SI1     60.0  61.0  2745  5.97 5.93 3.57 60.0

# %%
# Note that distance is in miles and air_time is in minutes
#
# add a speed variable in m.p.h. obtained by dividing distance and air_time, then
# select only speed and distance, then
# plot a scatter of speed (y axis) vs distance (x axis)
library(nycflights13)
mutate(flights, speed = 60*distance/air_time) %>%
    select(flights, distance, air_time) %>%
    ggplot(mapping = aes(x = distance, y = air_time)) +
        geom_point()
# Out:
# Error: `flights` must evaluate to column positions or names, not a list
# Traceback:
#
# 1. mutate(flights, speed = 60 * distance/air_time) %>% select(flights,
#  .     distance, air_time) %>% ggplot(mapping = aes(x = distance,
#  .     y = air_time))
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. function_list[[i]](value)
# 8. select(., flights, distance, air_time)
# 9. select.data.frame(., flights, distance, air_time)
# 10. tidyselect::vars_select(tbl_vars(.data), !!!enquos(...))
# 11. bad_calls(bad, "must evaluate to { singular(.vars) } positions or names, \\\n       not { first_type }")
# 12. glubort(fmt_calls(calls), ..., .envir = .envir)
# 13. .abort(text)
# 14. signal_abort(cnd)

# %%
mutate(flights, speed = 60*distance/air_time) %>%
    select(speed, distance) %>%
    ggplot(mapping = aes(x = distance, y = speed)) +
        geom_point()

# %%
# show a bar chart of average highway mileage of vehicle produced by each manufacturer
# manufacturer names are long so make sure to flip the coordinate axes in the bar chart
mpg %>%
    group(manufacturer) %>%
    summarize(average_hwy = mean(hwy)) %>%
    ggplot() %>%
        geom_bar(mapping = aes(x = manufacturer, y = hwy)) +
        coord_flip()
# Out:
# Error in group(., manufacturer): could not find function "group"
# Traceback:
#
# 1. mpg %>% group(manufacturer) %>% summarize(average_hwy = mean(hwy)) %>%
#  .     ggplot() %>% geom_bar(mapping = aes(x = manufacturer, y = hwy))
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. function_list[[i]](value)

# %%
mpg %>%
    group_by(manufacturer) %>%
    summarize(average_hwy = mean(hwy)) %>%
    ggplot() +
        geom_bar(mapping = aes(x = manufacturer, y = average_hwy), stat = "identity") +
        coord_flip()
# Out:
# plot without title

# %% [markdown]
# # EDA

# %% [markdown]
# Write the command to produce the following plot.
#
# Note that the `speed` (in m.p.h.) variable has been computed using `distance` (in miles) and `air_time` (in minutes) variables. `binwidth` was 10 m.p.h.
#
# ![plot](http://dept.stat.lsa.umich.edu/~tewaria/teaching/STATS306-Fall2017/Rplot5.png)

# %%
mutate(flights, speed = 60*distance/air_time) %>%
    ggplot() +
        geom_histogram(aes(x=speed), binwidth=10)
# Out:
# Warning message:
# “Removed 9430 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# Write the command to produce the following plot using the `mpg` data set.
#
# ![plot](http://dept.stat.lsa.umich.edu/~tewaria/teaching/STATS306-Fall2017/Rplot6.png)

# %%
ggplot(mpg) +
    geom_bar(aes(x=manufacturer,fill=class)) +
    coord_flip()
# Out:
# plot without title

# %% [markdown]
# Write the command to produce the following plot using the `mpg` data set.
#
# ![plot](http://dept.stat.lsa.umich.edu/~tewaria/teaching/STATS306-Fall2017/Rplot7.png)

# %%
ggplot(mpg) +
    geom_boxplot(aes(x=manufacturer,y=hwy)) +
    coord_flip()
# Out:
# plot without title

# %% [markdown]
# Write the command to produce the following plot.
#
# Note that the `speed` (in m.p.h.) variable has been computed using `distance` (in miles) and `air_time` (in minutes)
#
# ![plot](http://dept.stat.lsa.umich.edu/~tewaria/teaching/STATS306-Fall2017/Rplot8.png)

# %%
mutate(flights, speed = 60*distance/air_time) %>%
    select(speed, distance) %>%
    ggplot(mapping = aes(x = distance, y = speed)) +
        geom_hex()
# Out:
# Warning message:
# “Removed 9430 rows containing non-finite values (stat_binhex).”
# plot without title
